# %% [markdown]
# ## **PorterStemmer**

# %%
from nltk.stem import PorterStemmer

words = ["hello","sit","sitting","bye","good bye","tata","will be back","gamer","gaming","coder","coding","programming","program","programmer","runnable","running","ran"]
stemming = PorterStemmer()

for word in words:
    print(word," : ",stemming.stem(word))
# Out:
# hello  :  hello
# sit  :  sit
# sitting  :  sit
# bye  :  bye
# good bye  :  good by
# tata  :  tata
# will be back  :  will be back
# gamer  :  gamer
# gaming  :  game
# coder  :  coder
# coding  :  code
# programming  :  program
# program  :  program
# programmer  :  programm
# runnable  :  runnabl
# running  :  run
# ran  :  ran

# %% [markdown]
# # RegexpStemmer

# %%
from nltk.stem import RegexpStemmer

reg_stemmer=RegexpStemmer('ing$|s$|e$|able$', min=4)

for word in words:
    print(word," : ",reg_stemmer.stem(word))
# Out:
# hello  :  hello
# sit  :  sit
# sitting  :  sitt
# bye  :  bye
# good bye  :  good by
# tata  :  tata
# will be back  :  will be back
# gamer  :  gamer
# gaming  :  gam
# coder  :  coder
# coding  :  cod
# programming  :  programm
# program  :  program
# programmer  :  programmer
# runnable  :  runn
# running  :  runn
# ran  :  ran

# %% [markdown]
# # SnowBallStemmer

# %%
from nltk.stem import SnowballStemmer
snowballsstemmer=SnowballStemmer('english')

for word in words:
    print(word+"---->"+snowballsstemmer.stem(word))
# Out:
# hello---->hello
# sit---->sit
# sitting---->sit
# bye---->bye
# good bye---->good by
# tata---->tata
# will be back---->will be back
# gamer---->gamer
# gaming---->game
# coder---->coder
# coding---->code
# programming---->program
# program---->program
# programmer---->programm
# runnable---->runnabl
# running---->run
# ran---->ran

# %%
stemming.stem("fairly"),stemming.stem("sportingly"),stemming.stem("goes")
# Out:
# ('fairli', 'sportingli', 'goe')

# %%
snowballsstemmer.stem("fairly"),snowballsstemmer.stem("sportingly"),snowballsstemmer.stem('goes')
# Out:
# ('fair', 'sport', 'goe')

# %%
snowballhindistemmer=SnowballStemmer('spanish')
snowballhindistemmer.stem("puñetazo")
# Out:
# 'puñetaz'
